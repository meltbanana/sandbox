# %%
import tqdm

def get_primes(max):
#Sieve of Eratosthenes
    indx = [i for i in range(max+1)]

    for i in range(len(indx)):
        if i>1 and indx[i]>0:
            count = 2
            while count*i <= max: 
                indx[count*i] = 0
                count += 1
        
        #progress bar
        #if i%(max//10) == 0:
        #    print(i)
    primes = []        
    for i in indx:
        if i>1: primes.append(i)
    
    return primes

# %%
n = 50000000
n2 = int(n ** (1/2))
n3 = int(n ** (1/3))
n4 = int(n ** (1/4))

primes = get_primes(n2)

lst2 = []
lst3 = []
lst4 = []

for i in tqdm.tqdm(primes):
    lst2.append(i**2)
    if i <= n3: lst3.append(i**3)
    if i <= n4: lst4.append(i**4)
        

print(f"2: {len(lst2)}, 3: {len(lst3)}, 4:{len(lst4)}")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 908/908 [00:00<00:00, 139069.86it/s]
# 2: 908, 3: 73, 4:23

# %%
result = set()

for x4 in tqdm.tqdm(lst4):
    for x3 in lst3:
        for x2 in lst2:
            summa = x2 + x3 + x4
            if  summa < n:
                result.add(summa)
            else:
                continue

print(len(result))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 23/23 [00:00<00:00, 30.51it/s]
# 1097343
